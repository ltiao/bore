# %%
# %matplotlib inline

# %%
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from scipy.io import loadmat

# %%
log_well_data = loadmat("../datasets/logwell.mat")
log_well_data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN, Created on: Mon Jan 30 22:13:10 2012',
#  '__version__': '1.0',
#  '__globals__': [],
#  'y': array([[112310, 112530, 113710, ..., 117110, 116480, 115780]], dtype=int32)}

# %%
y = log_well_data['y'].squeeze()
y
# Out:
# array([112310, 112530, 113710, ..., 117110, 116480, 115780], dtype=int32)

# %%
fig, ax = plt.subplots()

ax.plot(y)

ax.set_xlabel(r'$t$')
ax.set_ylabel(r'$y_t$')

plt.show()
